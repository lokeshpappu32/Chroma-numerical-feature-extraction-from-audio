# %%
import os
import librosa
import numpy as np

# Directory path containing the audio files
directory = 'C:/Users/LOKESH PAPPU/Desktop/NITW/day 11/Mozilla Dataset Adult/Female/'

# Define the number of chroma features
num_chroma_features = 12

# Initialize an empty list to store the extracted chroma features
all_chroma_features = []

# Iterate over all files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.mp3'):
        file_path = os.path.join(directory, filename)
        
        # Load the speech signal
        signal, sr = librosa.load(file_path, sr=None)
        
        # Extract chroma features
        chroma_features = np.mean(librosa.feature.chroma_stft(y=signal, sr=sr, n_chroma=num_chroma_features).T, axis=0)
        
        # Append the chroma features to the list
        all_chroma_features.append(chroma_features)

# Convert the list of chroma features to a numpy array
all_chroma_features = np.array(all_chroma_features)

# %%
all_chroma_features
# Out:
# array([[0.41700324, 0.3506385 , 0.33201128, ..., 0.54208064, 0.5583967 ,
#         0.51691085],
#        [0.4784513 , 0.40573314, 0.29214385, ..., 0.4176509 , 0.5155475 ,
#         0.51277816],
#        [0.42477354, 0.31148303, 0.25212792, ..., 0.38669267, 0.57711536,
#         0.60496366],
#        ...,
#        [0.3607139 , 0.3371329 , 0.30275625, ..., 0.40821984, 0.46297768,
#         0.4069928 ],
#        [0.28814086, 0.2745435 , 0.27064034, ..., 0.42374524, 0.3522017 ,
#         0.34507477],
#        [0.36828944, 0.34759864, 0.2948612 , ..., 0.38499686, 0.46430966,
#         0.4127897 ]], dtype=float32)

# %%
import pandas as pd
df=pd.DataFrame(all_chroma_features)

# %%
df
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.417003  0.350639  0.332011  0.340794  0.285053  0.250544  0.266142
# 1    0.478451  0.405733  0.292144  0.276273  0.253380  0.224189  0.207778
# 2    0.424774  0.311483  0.252128  0.252913  0.285503  0.312215  0.248522
# 3    0.396558  0.355357  0.258257  0.278554  0.321217  0.296087  0.279108
# 4    0.412816  0.317344  0.268183  0.296444  0.269331  0.260707  0.310878
# ..        ...       ...       ...       ...       ...       ...       ...
# 745  0.328729  0.301975  0.244166  0.228634  0.264388  0.284362  0.356904
# 746  0.253782  0.236223  0.200342  0.171411  0.265735  0.347626  0.415579
# 747  0.360714  0.337133  0.302756  0.231292  0.240342  0.277733  0.291120
# 748  0.288141  0.274543  0.270640  0.255410  0.315506  0.358069  0.369546
# 749  0.368289  0.347599  0.294861  0.294093  0.301528  0.303168  0.338316
#
#            7         8         9         10        11
# ...

# %%
df["gender"]="female"
df["label"]="adult"

# %%
df.to_csv("Adult_Female_chroma_Features.csv",index=False)

# %%
import os
import librosa
import numpy as np

# Directory path containing the audio files
directory = 'C:/Users/LOKESH PAPPU/Desktop/NITW/day 11/Mozilla Dataset Adult/Male/'

# Define the number of chroma features
num_chroma_features = 12

# Initialize an empty list to store the extracted chroma features
all_chroma_features = []

# Iterate over all files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.mp3'):
        file_path = os.path.join(directory, filename)
        
        # Load the speech signal
        signal, sr = librosa.load(file_path, sr=None)
        
        # Extract chroma features
        chroma_features = np.mean(librosa.feature.chroma_stft(y=signal, sr=sr, n_chroma=num_chroma_features).T, axis=0)
        
        # Append the chroma features to the list
        all_chroma_features.append(chroma_features)

# Convert the list of chroma features to a numpy array
all_chroma_features = np.array(all_chroma_features)
import pandas as pd
df=pd.DataFrame(all_chroma_features)
df["gender"]="male"
df["label"]="adult"
df.to_csv("Adult_Male_chroma_Features.csv",index=False)

# %%
import os
import librosa
import numpy as np

# Directory path containing the audio files
directory = 'C:/Users/LOKESH PAPPU/Desktop/NITW/day 11/Dataset Child/Male/'

# Define the number of chroma features
num_chroma_features = 12

# Initialize an empty list to store the extracted chroma features
all_chroma_features = []

# Iterate over all files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.wav'):
        file_path = os.path.join(directory, filename)
        
        # Load the speech signal
        signal, sr = librosa.load(file_path, sr=None)
        
        # Extract chroma features
        chroma_features = np.mean(librosa.feature.chroma_stft(y=signal, sr=sr, n_chroma=num_chroma_features).T, axis=0)
        
        # Append the chroma features to the list
        all_chroma_features.append(chroma_features)

# Convert the list of chroma features to a numpy array
all_chroma_features = np.array(all_chroma_features)
import pandas as pd
df=pd.DataFrame(all_chroma_features)
df["gender"]="male"
df["label"]="child"
df.to_csv("Child_Male_chroma_Features.csv",index=False)

# %%
import os
import librosa
import numpy as np

# Directory path containing the audio files
directory = 'C:/Users/LOKESH PAPPU/Desktop/NITW/day 11/Dataset Child/Female'

# Define the number of chroma features
num_chroma_features = 12

# Initialize an empty list to store the extracted chroma features
all_chroma_features = []

# Iterate over all files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.wav'):
        file_path = os.path.join(directory, filename)
        
        # Load the speech signal
        signal, sr = librosa.load(file_path, sr=None)
        
        # Extract chroma features
        chroma_features = np.mean(librosa.feature.chroma_stft(y=signal, sr=sr, n_chroma=num_chroma_features).T, axis=0)
        
        # Append the chroma features to the list
        all_chroma_features.append(chroma_features)

# Convert the list of chroma features to a numpy array
all_chroma_features = np.array(all_chroma_features)
import pandas as pd
df=pd.DataFrame(all_chroma_features)
df["gender"]="female"
df["label"]="child"
df.to_csv("Child_Female_chroma_Features.csv",index=False)
